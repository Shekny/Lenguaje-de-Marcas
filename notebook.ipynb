# %% [markdown]
# ## Aprendiendo notebooks de Python

# %% [markdown]
# Voy a hacer mi primer hola mundo en este notebook.

# %%
print("Hola mundo")
# Out:
# Hola mundo

# %%
(2 + 3) % 2
# Out:
# 1

# %%
#!pip install matplotlib
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.scatter(x=[1, 2, 3], y=[1.3, 1.2, 1.1])
#plt.savefig('diagrama-dispersion.png')
plt.show()

# %%
num = 5
if(num % 2 == 0):
    print("Es par")
else:
    print("Es impar")
# Out:
# Es impar
